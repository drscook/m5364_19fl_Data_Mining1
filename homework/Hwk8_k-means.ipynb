# %% [markdown]
# ### Math 5364 - Data mining I - Tarleton State Univ - Dr. Scott Cook - Fall 2019
# Assignment 8 - due 2019/10/22
#
# Get the iris dataset and write code to implement $k$-mean clustering on it without using sklearn.  Then use sklearn $k$-means to check your answers.
