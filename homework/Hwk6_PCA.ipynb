# %% [markdown]
# ### Math 5364 - Data mining I - Tarleton State Univ - Dr. Scott Cook - Fall 2019
# Assignment 6 - due 2019/10/08
#
# Get the iris dataset and write code to implement Principal Components Analysis (PCA) on it without using sklearn or np.cov.  Then use the sklearn PCA to check your answers.
