# %% [markdown]
# ### Math 5364 - Data mining I - Tarleton State Univ - Dr. Scott Cook - Fall 2019
# Assignment 7 - due 2019/10/15
#
# Get the iris dataset and write code to implement $k$-nearest neighbors on it without using sklearn.  Then use the sklearn $k$-nearest neighbors to check your answers.
